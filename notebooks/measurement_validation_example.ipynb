# %% [markdown]
# This is a notebook for non-Linux systems.

# %% [markdown]
# DO NOT ERASE ANYTHING HERE.

# %%
import sys
sys.path.append("..")
# import os; os.chdir(os.path.dirname(os.getcwd()))
#Make sure that jupyter has admin rights. As well as during terminal run, use sudo! ON any platform
#sudo jupyter notebook --allow-root would help you
from main_validation import launch_measurement

# %%
import pandas as pd

# Set pandas options to display all columns and rows
pd.set_option('display.max_columns', None)  # Display all columns
pd.set_option('display.max_rows', None)     # Display all rows
pd.set_option('display.max_colwidth', None) # Display full column width

# %% [markdown]
# In the cell below, the framework Adult dataset, which has been preprocessed (without MinMaxScaler and One-Hot encoding!).

# %%
# Filename that you will use (put it in preparation_files/datasets)
filename = 'Adult_v2'

# Target attribute, that will be used for ML tasks
target = 'income'

num_to_categ = None

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['age', 'sex', 'race', 'country'], ['occupation', 'capital_gain', 'type_employer']] 

# Can be one attribute or None
# secret = 'marital' 
secret = None 


# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')
# Out:
# This is a SubSystem for Linux
# Executing the framework for non-Linux systems
# Reminder: Please clean and preprocess the dataset before the execution of the framework (without MinMaxScaler and One-Hot encoding!).
# Data must not be altered!
# You have a single file!
#
# Categorical attributes: ['type_employer', 'education', 'marital', 'occupation', 'relationship', 'race', 'sex', 'country', 'income']
# Continuous attributes: ['age', 'capital_gain', 'capital_loss', 'hr_per_week']
#
# Please check the data type of attributes. Stop the process if necessary.
# Folder './output/YmQ99SqbWb' created successfully.
# Iteration's ID is: YmQ99SqbWb !
#
#
# The categorical attribute with the most unique values is 'country' with 40 unique values.
# Threshold for data synthesis generation is 41.
#
#
# Epsilon value is 0.
# Synthetic Data generation has started. Please wait...

# %% [markdown]
# In the cell below, the framework Student Performance dataset, which has been preprocessed (without MinMaxScaler and One-Hot encoding!).

# %%
filename = 'student-por'

# Target attribute, that will be used for ML tasks
target = 'G3'

#Which integer attributes can be considered categorical attributes
num_to_categ = ['G1', 'G2']

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['age', 'sex', 'address'], ['G1', 'G2', 'absences']] 

# Can be one attribute or None
# secret = put your secret here 
secret = 'health' 

# For save_my_report_to_csv= put either 'Y' if yes or None for no.
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %% [markdown]
# In the cell below, the framework Abalone dataset, which has been preprocessed (without MinMaxScaler and One-Hot encoding!).

# %%
# Filename that you will use (put it in preparation_files/datasets)
filename = 'abalone'

# Target attribute, that will be used for ML tasks
target = 'age_category'

num_to_categ = None

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['sex', 'length', 'diameter'], ['whole_weight', 'shucked_weight', 'viscera_weight']] 

# Can be one attribute or None
# secret = 'marital' 
secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
"""
num_to_categ = None
bank-full:
Categorical attributes: ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'subscription', 'contacted_before']
continuous attributes: ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'] 


bank:
Categorical attributes: ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'subscription', 'contacted_before']
continuous attributes: ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'] 



num_to_categ = ['day']

bank-full:
Categorical attributes: ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'day', 'month', 'poutcome', 'subscription', 'contacted_before']
continuous attributes: ['age', 'balance', 'duration', 'campaign', 'pdays', 'previous']

"""

#bank stuff

filename = 'bank'

# Target attribute, that will be used for ML tasks
target = 'subscription'

num_to_categ = ['day']

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['age', 'marital', 'job'], ['housing', 'loan', 'balance']] 

# Can be one attribute or None
# secret = 'marital' 
secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'bank-full'

# Target attribute, that will be used for ML tasks
target = 'subscription'

num_to_categ = ['day']

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['age', 'marital', 'job'], ['housing', 'loan', 'balance']] 

# Can be one attribute or None
# secret = 'marital' 
secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'autism'

# Target attribute, that will be used for ML tasks
target = 'class'

num_to_categ = None

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['age', 'gender', 'ethnicity'], ['result', 'relation']] 

# Can be one attribute or None
# secret = 'marital' 
secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
'''
Categorical attributes: ['status', 'credit_history', 'purpose', 'savings_account_bonds', 'present_employment_since', 'personal_status_and_sex', 'other_debtors_guarantors', 'property', 'other_installment_plans', 'housing', 'job', 'n_people_liable_maintenance', 'telephone', 'foreign_worker', 'class']
continuous attributes: ['duration_in_month', 'credit_amount', 'installment_rate_in_percentage_of_disposable_income', 'present_residence_since', 'age_in_years', 'existing_credits'] 
'''


filename = 'german'

# Target attribute, that will be used for ML tasks
target = 'class'

num_to_categ = None

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['personal_status_and_sex','status', 'job', 'housing'], ['savings_account_bonds', 'credit_history', "credit_amount"]] 

# Can be one attribute or None
# secret = 'marital' 
secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
#ALL MUST BE CATEGORICAL!
filename = 'nursery'

# Target attribute, that will be used for ML tasks
target = 'class_encoded'

num_to_categ = ['class_encoded']

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['parents','social', 'children'], ['finance', 'housing']] 

# Can be one attribute or None
# secret = 'marital' 
secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'obesity'

# Target attribute, that will be used for ML tasks
target = 'Obesity_level'

num_to_categ = None

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['Age','Height', 'Weight'], ['How_many_meals', 'between_meals', 'Monitor_cals']] 

# Can be one attribute or None
# secret = 'marital' 
secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'productivity_garment'

# Target attribute, that will be used for ML tasks
target = 'actual_productivity'

num_to_categ = ['day', 'month']

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['day_of_the_week','team', 'department'], ['targeted_productivity', 'over_time', 'no_of_workers']] 

# Can be one attribute or None
# secret = 'marital' 
secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'catheterization'

# Target attribute, that will be used for ML tasks
target = 'death'
"""
Categorical attributes: ['category1', 'category2', 'cancer', 'death', 'cardio_hist', 'chf_hist', 
'dementia_hx', 'psych_hist', 'pulm_hist', 'renal_hist', 'liver_hist', 'gi_hist', 'malign_hist', 
'immuno_hist', 'trans_hist', 'ami_hist', 'sex', 'dth30', 'swang1', 'dnr_status', 'insurance', 
'respiratory', 'cardiac', 'neurologic', 'gastric', 'renal_cond', 'metabolic', 'hematologic',
 'sepsis', 'trauma_cond', 'ortho_cond', 'race', 'income']
Continuous attributes: ['adm_date', 'discharge_date', 'last_con_dt', 'age', 'edu_years',
 '2m_survival', 'das2d_3pc', 't3d30', 'aps1', 'scoma1', 'meanbp1', 'wblc1', 'hrt1', 
 'resp1', 'temperature', 'pafi1', 'alb1', 'hema1', 'bili1', 'crea1', 'sod1', 'pot1', 
 'paco21', 'ph1', 'wtkilo1', 'adld3p', 'urin1', 'ptid'] 


"""

num_to_categ = None

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['edu_years','sex', 'age'], ['insurance', 'category1', 'cancer']] 

# Can be one attribute or None
# secret = 'marital' 
secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'coupons'

# Target attribute, that will be used for ML tasks
target = 'coupon_accepted'
#age and temperature in this situation are categorical
num_to_categ = None
# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['age','gender', 'maritalStatus'], ['coupon', 'expiration', 'car']] 

# Can be one attribute or None
# secret = 'marital' 
secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'default_credit'

# Target attribute, that will be used for ML tasks
target = 'def_payment'

num_to_categ = ['education', 'marriage']

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['age','marriage', 'sex'], ['limit_bal', 'education', 'pay_0']] 

# Can be one attribute or None
# secret = 'marital' 
secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'diabetes'

# Target attribute, that will be used for ML tasks
target = 'readmitted'

num_to_categ = ['admission_type_id', 'discharge_disposition_id', 'admission_source_id']

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['gender','age', 'race'], ['payer_code', 'medical_specialty', 'time_in_hospital']] 

# Can be one attribute or None
# secret = 'marital' 
secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'indian'

# Target attribute, that will be used for ML tasks
target = 'is_patient'

num_to_categ = None

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['age','gender', 'is_patient'], ['total_bilirubin', 'direct_bilirubin', 'total_proteins']] 

# Can be one attribute or None
# secret = 'marital' 
secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'recipes'

# Target attribute, that will be used for ML tasks
target = 'best_score'

num_to_categ = None

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['user_reputation','reply_count', 'stars'], ['thumbs_up', 'thumbs_down']] 

# Can be one attribute or None
# secret = 'marital' 
secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'support2'

# Target attribute, that will be used for ML tasks
target = 'hospdead'

num_to_categ = ['edu', 'prg6m', 'adlp']

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['sex','age', 'race', 'edu'], ['charges', 'income', 'dzgroup']] 
# spport2_2 = [['ca','dementia', 'diabetes'], ['ph', 'dnr', 'hrt']] 
# spport2_3 = [['resp','ph', 'adlp'], ['sfdm2', 'adls', 'ph']] 
# the rest of support
# Can be one attribute or None
# secret = 'marital' 
secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'taiwan_bankrupt'

# Target attribute, that will be used for ML tasks
target = 'bankrupt'

num_to_categ = None

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['current_liability_assets','cash_current_liability', 'operating_funds_liability'], ['fixed_assets_per_employee', 'sales_per_employee', 'operating_income_per_employee']] 

#t_2 = [['current_assets_sales','working_capital_sales', 'quick_assets_sales'], ['cash_sales', 'cash_flow_sales', 'cash_flow_operating_current_liabilities']] 
#t_3 = [['current_assets_sales','working_capital_sales', 'quick_assets_sales'], ['cash_sales', 'cash_flow_sales', 'cash_flow_operating_current_liabilities']] 

# Can be one attribute or None
# secret = 'marital' 
secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'dropout'

# Target attribute, that will be used for ML tasks
target = 'target'

num_to_categ = ['marital_status', 'application_mode', 'application_order', 'course',
       'daytime/evening_attendance', 'previous_qualification',
       'previous_qualification_(grade)', 'nationality',
       'mother\'s_qualification', 'father\'s_qualification',
       'mother\'s_occupation', 'father\'s_occupation']

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['marital_status', 'nationality', 'gender'], ['admission_grade', 'age_at_enrollment', 'course']] 


secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'bitcoin'

# Target attribute, that will be used for ML tasks
target = 'label'

num_to_categ = ['label']

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['year', 'length', 'day'], ['income', 'label']] 


secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'drugs'

# Target attribute, that will be used for ML tasks
target = 'nicotine'

num_to_categ = ['nicotine']

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['age', 'gender', 'ethnicity'], ['nscore', 'escore', 'oscore']] 


secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'egyptian'

# Target attribute, that will be used for ML tasks
target = 'baseline_histological_staging'

num_to_categ = ['baseline_histological_grading','baseline_histological_staging']

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['age', 'gender', 'bmi'], ['fatigue_bone_ache', 'jaundice', 'baseline_histological_grading']] 


secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'hcv'

# Target attribute, that will be used for ML tasks
target = 'category'

num_to_categ = ['category']

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['age', 'sex'], ['chol', 'bil', 'crea']] 


secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'heart_failure'

# Target attribute, that will be used for ML tasks
target = 'death_event'

num_to_categ = None

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['age', 'sex', 'smoking'], ['high_blood_pressure', 'diabetes', 'creatinine_phosphokinase']] 


secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')

# %%
filename = 'hepatitis'

# Target attribute, that will be used for ML tasks
target = 'class'

num_to_categ = None

# Can be 1 dataset as 1 list or 2 datasets inside of 1 list. 
possible_known_attributes = [['age', 'sex', 'class'], ['anorexia', 'fatigue', 'spiders']] 


secret = None 

#Testing now without CSV and production of the HTML report!
# For save_my_report_to_csv= put either 'Y' if yes or None for no.
launch_measurement(input_filename= filename, target_attribute_ML= target, num_to_categ=num_to_categ, possible_known_attributes= possible_known_attributes, secret_mode= secret, save_my_report_to_csv= 'N')
